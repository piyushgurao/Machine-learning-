# %% [markdown]
# ## Decision tree regressor

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes=load_diabetes()

# %%
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]], shape=(442, 10)),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
print(diabetes['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
X=pd.DataFrame(diabetes.data,columns=diabetes.feature_names)

# %%
X
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
X.shape
# Out:
# (442, 10)

# %%
y=pd.DataFrame(diabetes.target,columns=['level'])

# %%
y
# Out:
#      level
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# ..     ...
# 437  178.0
# 438  104.0
# 439  132.0
# 440  220.0
# 441   57.0
#
# [442 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_train.shape
# Out:
# (309, 10)

# %%
#correlation between X_train data
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.197408  0.198359  0.394903  0.238375  0.192920 -0.128403
# sex  0.197408  1.000000  0.108261  0.221914  0.057674  0.180315 -0.379464
# bmi  0.198359  0.108261  1.000000  0.356324  0.226047  0.248146 -0.395021
# bp   0.394903  0.221914  0.356324  1.000000  0.238295  0.165632 -0.192505
# s1   0.238375  0.057674  0.226047  0.238295  1.000000  0.872781  0.006313
# s2   0.192920  0.180315  0.248146  0.165632  0.872781  1.000000 -0.265114
# s3  -0.128403 -0.379464 -0.395021 -0.192505  0.006313 -0.265114  1.000000
# s4   0.227110  0.324882  0.412826  0.249141  0.559626  0.684840 -0.754616
# s5   0.314151  0.150956  0.435505  0.420236  0.566312  0.325759 -0.370523
# s6   0.351570  0.193322  0.358273  0.368882  0.356280  0.315890 -0.297055
#
#            s4        s5        s6
# age  0.227110  0.314151  0.351570
# sex  0.324882  0.150956  0.193322
# bmi  0.412826  0.435505  0.358273
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15,10));
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## HyperParameter Tuning

# %%
param={
    'criterion':['squared_error', 'friedman_mse', 'absolute_error'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5,10,15,20,25],
    'max_features':['auto','sqrt','log2']
}

# %%
param
# Out:
# {'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
#  'splitter': ['best', 'random'],
#  'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(DecisionTreeRegressor(),param_grid=param,cv=5,refit=True,scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'splitter': 'best'}

# %%
grid.best_score_
# Out:
# np.float64(-4020.1356160761497)

# %%
grid.estimator
# Out:
# DecisionTreeRegressor()

# %%
grid.score(X_test,y_test)
# Out:
# -5710.791211671119

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
y_pred=grid.predict(X_test)

# %%
print("r2_score: ",r2_score(y_test,y_pred))
print("mean absolute error :", mean_absolute_error(y_test,y_pred))
print("mean square error :", mean_squared_error(y_test,y_pred))
# Out:
# r2_score:  0.2685711047709528
# mean absolute error : 52.939847550444384
# mean square error : 4628.241478411161

# %% [markdown]
# ## visulize the model

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'splitter': 'best'}

# %%
regressor=DecisionTreeRegressor(**grid.best_params_)

# %%
regressor.get_params
# Out:
# <bound method BaseEstimator.get_params of DecisionTreeRegressor(max_depth=5, max_features='sqrt')>

# %%
regressor
# Out:
# DecisionTreeRegressor(max_depth=5, max_features='sqrt')

# %%
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, max_features='sqrt')

# %%
# visualize decision tree
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(regressor,filled=True)
# Out:
# [Text(0.48660714285714285, 0.9166666666666666, 'x[2] <= 0.016\nsquared_error = 5757.456\nsamples = 309\nvalue = 152.738'),
#  Text(0.24553571428571427, 0.75, 'x[8] <= -0.004\nsquared_error = 3732.377\nsamples = 205\nvalue = 125.498'),
#  Text(0.36607142857142855, 0.8333333333333333, 'True  '),
#  Text(0.13392857142857142, 0.5833333333333334, 'x[0] <= 0.022\nsquared_error = 2200.983\nsamples = 120\nvalue = 101.508'),
#  Text(0.07142857142857142, 0.4166666666666667, 'x[2] <= 0.006\nsquared_error = 2062.143\nsamples = 93\nvalue = 94.914'),
#  Text(0.03571428571428571, 0.25, 'x[3] <= 0.101\nsquared_error = 1782.246\nsamples = 89\nvalue = 91.438'),
#  Text(0.017857142857142856, 0.08333333333333333, 'squared_error = 1624.181\nsamples = 88\nvalue = 90.023'),
#  Text(0.05357142857142857, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 216.0'),
#  Text(0.10714285714285714, 0.25, 'x[3] <= -0.033\nsquared_error = 2040.188\nsamples = 4\nvalue = 172.25'),
# ...
